# %% [markdown]
# Mi primer script

# %%
2 + 3
# Out:
# 5

# %%
A = 3;

# %%
B = 6

# %%
C = A + B

# %%
C
# Out:
# 9

# %% [markdown]
# Multiplicación de Variables

# %%
D = A*B
D
# Out:
# 18

# %% [markdown]
# Suma de dos variables

# %%
num1 = 5
num2 = 10
suma = num1 + num2
print("La suma es:", suma)
# Out:
# La suma es: 15

# %% [markdown]
# Resta de dos Variables

# %%
num1 = 20
num2 = 10
resta = num1 - num2
print("La resta es:", resta)
# Out:
# La resta es: 10

# %% [markdown]
# Area de un triangulo

# %%
base= 10
altura = 20
area = ( base*altura)/2
print("El area del triangulo es ", area)
# Out:
# El area del triangulo es  100.0

# %% [markdown]
# Area del rectangulo

# %%
base = 5
altura = 7
area = (base * altura)
print("El area del rectangulo es:", area)
# Out:
# El area del rectangulo es: 35

# %% [markdown]
# Area del Circulo

# %%
import math

radio = 5
circulo = math.pi * (radio ** 2)

print('El area del circulo es: ', round(circulo, 2), 'm2')
# Out:
# El area del circulo es:  78.54 m2

# %%
n1 = input("Introduce el pimer valor: ")
n2 = input("Introduce el segundo  valor:")
suma = n1 + n2
print("La suma es:", suma)
# Out:
# La suma es: 510

# %%
n1 = int(input("Introduce el pimer valor: "))
n2 = int(input("Introduce el segundo  valor:"))
suma = n1 + n2
print("La suma es:", suma)
# Out:
# La suma es: 15
